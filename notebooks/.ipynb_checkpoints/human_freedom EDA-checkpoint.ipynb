# %% [markdown]
# # THE HUMAN FREEDOM INDEX

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### Import relevant packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno

# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Data

# %% [markdown]
# Source: https://www.kaggle.com/gsutters/the-human-freedom-index/version/2#_=_

# %%
hf_df = pd.read_csv('../data/human_freedom.csv')

# %% [markdown]
# ### Viewing the data

# %%
hf_df.head()
# Out:
#    year ISO_code  countries                         region  hf_score  hf_rank  hf_quartile
# 0  2016      ALB    Albania                 Eastern Europe  7.568140     48.0          2.0
# 1  2016      DZA    Algeria     Middle East & North Africa  5.135886    155.0          4.0
# 2  2016      AGO     Angola             Sub-Saharan Africa  5.640662    142.0          4.0
# 3  2016      ARG  Argentina  Latin America & the Caribbean  6.469848    107.0          3.0
# 4  2016      ARM    Armenia        Caucasus & Central Asia  7.241402     57.0          2.0

# %% [markdown]
# ##### Data types of the variables

# %%
hf_df.dtypes
# Out:
# year             int64
# ISO_code        object
# countries       object
# region          object
# hf_score       float64
# hf_rank        float64
# hf_quartile    float64
# dtype: object

# %% [markdown]
# ##### Summary statistics

# %%
hf_df.describe()
# Out:
#               year     hf_score      hf_rank  hf_quartile
# count  1378.000000  1378.000000  1378.000000  1378.000000
# mean   2012.111756     6.993444    77.007983     2.490566
# std       2.569130     1.025811    44.506549     1.119698
# min    2008.000000     3.765827     1.000000     1.000000
# 25%    2010.000000     6.336685    39.000000     1.000000
# 50%    2012.000000     6.923840    76.000000     2.000000
# 75%    2014.000000     7.894660   115.000000     3.000000
# max    2016.000000     9.126313   162.000000     4.000000

# %% [markdown]
# ### Removing country data that is not complete for all years

# %% [markdown]
# ##### Getting list of country names that don't have data for all the years

# %%
countries_year_count = hf_df.groupby(['countries']).size().reset_index().rename(columns={0:'count'})
country_missing_data = list(countries_year_count.loc[countries_year_count['count'] != 9]['countries'])
country_missing_data
# Out:
# ['Belarus',
#  'Bhutan',
#  'Brunei Darussalam',
#  'Cambodia',
#  'Cape Verde',
#  'Gambia, The',
#  'Guinea',
#  'Iraq',
#  'Laos',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Qatar',
#  'Saudi Arabia',
#  'Seychelles',
#  'Sudan',
#  'Suriname',
#  'Swaziland',
#  'Tajikistan',
#  'Timor-Leste',
#  'Yemen, Rep.']

# %% [markdown]
# ##### Getting country data that have data for all the years

# %%
hf_country_years_complete = hf_df[~hf_df['countries'].isin(country_missing_data)]

# %% [markdown]
# ##### Double-checking that countries have data for all 9 years

# %%
hf_country_years_complete['countries'].value_counts()
# Out:
# Spain                     9
# Tunisia                   9
# Latvia                    9
# Estonia                   9
# Venezuela                 9
# Malaysia                  9
# Azerbaijan                9
# Burundi                   9
# Lithuania                 9
# Netherlands               9
# Turkey                    9
# Sierra Leone              9
# Austria                   9
# Cameroon                  9
# Zimbabwe                  9
# Botswana                  9
# Belize                    9
# Ireland                   9
# Hungary                   9
# Zambia                    9
# Barbados                  9
# Honduras                  9
# Sweden                    9
# Nigeria                   9
# Philippines               9
# Egypt                     9
# El Salvador               9
# Ethiopia                  9
# Belgium                   9
# Sri Lanka                 9
# Denmark                   9
# Guatemala                 9
# Luxembourg                9
# Bahamas                   9
# Indonesia                 9
# New Zealand               9
# Guyana                    9
# Mauritania                9
# Cote d'Ivoire             9
# Ecuador                   9
# Kyrgyz Republic           9
# Kuwait                    9
# Macedonia                 9
# China                     9
# Peru                      9
# Montenegro                9
# Russia                    9
# United Kingdom            9
# Thailand                  9
# Central Afr. Rep.         9
# Togo                      9
# Angola                    9
# Colombia                  9
# Congo, Dem. R.            9
# Paraguay                  9
# United Arab Emirates      9
# Nicaragua                 9
# Ukraine                   9
# Iceland                   9
# Bulgaria                  9
# Japan                     9
# Dominican Rep.            9
# Iran                      9
# Finland                   9
# Brazil                    9
# Malawi                    9
# Chad                      9
# Pap. New Guinea           9
# France                    9
# Guinea-Bissau             9
# Albania                   9
# Madagascar                9
# Myanmar                   9
# India                     9
# Armenia                   9
# Morocco                   9
# Ghana                     9
# Bahrain                   9
# Haiti                     9
# Mongolia                  9
# Korea, South              9
# Portugal                  9
# Bolivia                   9
# Hong Kong                 9
# Oman                      9
# Israel                    9
# Mozambique                9
# Taiwan                    9
# Slovenia                  9
# Norway                    9
# Syria                     9
# Lesotho                   9
# Uganda                    9
# Argentina                 9
# Kenya                     9
# Rwanda                    9
# Poland                    9
# Trinidad and Tobago       9
# Panama                    9
# Serbia                    9
# Gabon                     9
# Mali                      9
# Jamaica                   9
# Senegal                   9
# Slovak Rep.               9
# Namibia                   9
# Czech Rep.                9
# Bangladesh                9
# Canada                    9
# Costa Rica                9
# Mexico                    9
# Benin                     9
# Greece                    9
# Pakistan                  9
# Congo, Rep. Of            9
# Niger                     9
# Singapore                 9
# Switzerland               9
# Australia                 9
# Germany                   9
# Croatia                   9
# Uruguay                   9
# Bosnia and Herzegovina    9
# Algeria                   9
# Moldova                   9
# Malta                     9
# Burkina Faso              9
# Kazakhstan                9
# Mauritius                 9
# South Africa              9
# Tanzania                  9
# Nepal                     9
# Romania                   9
# Cyprus                    9
# Vietnam                   9
# Georgia                   9
# Jordan                    9
# United States             9
# Fiji                      9
# Italy                     9
# Chile                     9
# Name: countries, dtype: int64

# %% [markdown]
# ### Has the world freedom changed over the years?
# - World freedom for a particular year is calculated by taking the mean of the country hf scores for that year
# - Only countries that have data for all the years are included

# %%
hf_country_years_complete.groupby(['year']).mean()['hf_score']
# Out:
# year
# 2008    7.069785
# 2009    7.075678
# 2010    7.075024
# 2011    7.076528
# 2012    7.030769
# 2013    7.053720
# 2014    7.041126
# 2015    7.017344
# 2016    7.010904
# Name: hf_score, dtype: float64

# %%
hf_country_years_complete.groupby(['year']).mean().plot.line(y='hf_score', use_index=True)

# %% [markdown]
# ##### What's the difference between the freedom in 2008 and 2016?

# %%
7.010904 - 7.069785
# Out:
# -0.058881000000000405

# %% [markdown]
# ### What are the countries with the most freedom? <br> Have they changed over the years?

# %%
for i in range(2008, 2017):
    print('\033[1m' + str(i) + '\033[0m')
    print(hf_df.loc[hf_df['year'] == i].sort_values(by=['hf_rank']).head(10))
# Out:
# 2008
#       year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 1293  2008      HKG       Hong Kong       East Asia  9.126313      1.0          1.0
# 1332  2008      NZL     New Zealand         Oceania  8.910542      2.0          1.0
# 1359  2008      CHE     Switzerland  Western Europe  8.774437      3.0          1.0
# 1242  2008      AUS       Australia         Oceania  8.686020      4.0          1.0
# 1273  2008      DNK         Denmark  Western Europe  8.687174      4.0          1.0
# 1260  2008      CAN          Canada   North America  8.653002      6.0          1.0
# 1281  2008      FIN         Finland  Western Europe  8.653871      6.0          1.0
# 1336  2008      NOR          Norway  Western Europe  8.592142      8.0          1.0
# 1371  2008      GBR  United Kingdom  Western Europe  8.536421      9.0          1.0
# 1299  2008      IRL         Ireland  Western Europe  8.464583     10.0          1.0
# 2009
#       year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 1152  2009      HKG       Hong Kong       East Asia  9.052653      1.0          1.0
# 1191  2009      NZL     New Zealand         Oceania  8.797717      2.0          1.0
# 1218  2009      CHE     Switzerland  Western Europe  8.792258      3.0          1.0
# 1119  2009      CAN          Canada   North America  8.638999      4.0          1.0
# 1101  2009      AUS       Australia         Oceania  8.630313      5.0          1.0
# 1140  2009      FIN         Finland  Western Europe  8.610269      6.0          1.0
# 1230  2009      GBR  United Kingdom  Western Europe  8.590177      7.0          1.0
# 1132  2009      DNK         Denmark  Western Europe  8.572328      8.0          1.0
# 1195  2009      NOR          Norway  Western Europe  8.460101      9.0          1.0
# 1217  2009      SWE          Sweden  Western Europe  8.415916     10.0          1.0
# 2010
#       year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 1003  2010      HKG       Hong Kong       East Asia  9.028448      1.0          1.0
# 1043  2010      NZL     New Zealand         Oceania  8.879077      2.0          1.0
# 1074  2010      CHE     Switzerland  Western Europe  8.818141      3.0          1.0
# 990   2010      FIN         Finland  Western Europe  8.645241      4.0          1.0
# 948   2010      AUS       Australia         Oceania  8.642693      5.0          1.0
# 968   2010      CAN          Canada   North America  8.640115      5.0          1.0
# 982   2010      DNK         Denmark  Western Europe  8.629381      7.0          1.0
# 1047  2010      NOR          Norway  Western Europe  8.515925      8.0          1.0
# 1073  2010      SWE          Sweden  Western Europe  8.509303      9.0          1.0
# 1088  2010      GBR  United Kingdom  Western Europe  8.451403     10.0          1.0
# 2011
#      year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 850  2011      HKG       Hong Kong       East Asia  9.027891      1.0          1.0
# 890  2011      NZL     New Zealand         Oceania  8.791730      2.0          1.0
# 921  2011      CHE     Switzerland  Western Europe  8.777166      3.0          1.0
# 837  2011      FIN         Finland  Western Europe  8.674685      4.0          1.0
# 815  2011      CAN          Canada   North America  8.607993      5.0          1.0
# 795  2011      AUS       Australia         Oceania  8.596251      6.0          1.0
# 829  2011      DNK         Denmark  Western Europe  8.592387      7.0          1.0
# 920  2011      SWE          Sweden  Western Europe  8.506445      8.0          1.0
# 935  2011      GBR  United Kingdom  Western Europe  8.494381      9.0          1.0
# 894  2011      NOR          Norway  Western Europe  8.462699     10.0          1.0
# 2012
#      year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 697  2012      HKG       Hong Kong       East Asia  8.999086      1.0          1.0
# 737  2012      NZL     New Zealand         Oceania  8.784639      2.0          1.0
# 768  2012      CHE     Switzerland  Western Europe  8.760105      3.0          1.0
# 684  2012      FIN         Finland  Western Europe  8.625452      4.0          1.0
# 662  2012      CAN          Canada   North America  8.598394      5.0          1.0
# 741  2012      NOR          Norway  Western Europe  8.574077      6.0          1.0
# 642  2012      AUS       Australia         Oceania  8.557936      7.0          1.0
# 676  2012      DNK         Denmark  Western Europe  8.523583      8.0          1.0
# 703  2012      IRL         Ireland  Western Europe  8.482832      9.0          1.0
# 782  2012      GBR  United Kingdom  Western Europe  8.472484     10.0          1.0
# 2013
#      year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 542  2013      HKG       Hong Kong       East Asia  8.971815      1.0          1.0
# 583  2013      NZL     New Zealand         Oceania  8.868585      2.0          1.0
# 615  2013      CHE     Switzerland  Western Europe  8.715262      3.0          1.0
# 506  2013      CAN          Canada   North America  8.627752      4.0          1.0
# 520  2013      DNK         Denmark  Western Europe  8.599675      5.0          1.0
# 587  2013      NOR          Norway  Western Europe  8.580085      6.0          1.0
# 528  2013      FIN         Finland  Western Europe  8.578115      6.0          1.0
# 485  2013      AUS       Australia         Oceania  8.543666      8.0          1.0
# 548  2013      IRL         Ireland  Western Europe  8.527786      9.0          1.0
# 629  2013      GBR  United Kingdom  Western Europe  8.512754     10.0          1.0
# 2014
#      year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 426  2014      NZL     New Zealand         Oceania  8.921386      1.0          1.0
# 383  2014      HKG       Hong Kong       East Asia  8.892456      2.0          1.0
# 458  2014      CHE     Switzerland  Western Europe  8.806932      3.0          1.0
# 347  2014      CAN          Canada   North America  8.719553      4.0          1.0
# 326  2014      AUS       Australia         Oceania  8.672342      5.0          1.0
# 369  2014      FIN         Finland  Western Europe  8.638353      6.0          1.0
# 361  2014      DNK         Denmark  Western Europe  8.607840      7.0          1.0
# 407  2014      LUX      Luxembourg  Western Europe  8.571140      8.0          1.0
# 430  2014      NOR          Norway  Western Europe  8.573282      8.0          1.0
# 472  2014      GBR  United Kingdom  Western Europe  8.532903     10.0          1.0
# 2015
#      year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 267  2015      NZL     New Zealand         Oceania  8.876890      1.0          1.0
# 224  2015      HKG       Hong Kong       East Asia  8.857581      2.0          1.0
# 299  2015      CHE     Switzerland  Western Europe  8.814458      3.0          1.0
# 230  2015      IRL         Ireland  Western Europe  8.645525      4.0          1.0
# 167  2015      AUS       Australia         Oceania  8.607373      5.0          1.0
# 210  2015      FIN         Finland  Western Europe  8.558935      6.0          1.0
# 266  2015      NLD     Netherlands  Western Europe  8.548259      7.0          1.0
# 202  2015      DNK         Denmark  Western Europe  8.543023      8.0          1.0
# 313  2015      GBR  United Kingdom  Western Europe  8.528704      9.0          1.0
# 188  2015      CAN          Canada   North America  8.520056     10.0          1.0
# 2016
#      year ISO_code       countries          region  hf_score  hf_rank  hf_quartile
# 107  2016      NZL     New Zealand         Oceania  8.887410      1.0          1.0
# 140  2016      CHE     Switzerland  Western Europe  8.787759      2.0          1.0
# 63   2016      HKG       Hong Kong       East Asia  8.776840      3.0          1.0
# 5    2016      AUS       Australia         Oceania  8.582219      4.0          1.0
# 27   2016      CAN          Canada   North America  8.565863      5.0          1.0
# 41   2016      DNK         Denmark  Western Europe  8.547820      6.0          1.0
# 106  2016      NLD     Netherlands  Western Europe  8.554421      6.0          1.0
# 154  2016      GBR  United Kingdom  Western Europe  8.497918      8.0          1.0
# 70   2016      IRL         Ireland  Western Europe  8.504565      8.0          1.0
# 111  2016      NOR          Norway  Western Europe  8.471241     10.0          1.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-ff59642c46f6> in <module>
#       4
#       5
# ----> 6 hf_df(hf_df['hf_rank'] < 11)
#
# TypeError: 'DataFrame' object is not callable

# %%
hf_df.loc[hf_df['hf_rank'] < 11]['countries'].unique()
# Out:
# array(['Australia', 'Canada', 'Denmark', 'Finland', 'Hong Kong',
#        'Ireland', 'Netherlands', 'New Zealand', 'Norway', 'Switzerland',
#        'Taiwan', 'United Kingdom', 'Austria', 'Luxembourg', 'Germany',
#        'Sweden'], dtype=object)

# %% [markdown]
# ### What are the countries with the least freedom? <br> Have they changed over the years?

# %%
for i in range(2008, 2017):
    print('\033[1m' + str(i) + '\033[0m')
    print(hf_df.loc[hf_df['year'] == i].sort_values(by=['hf_rank']).tail(10))
# Out:
# 2008
#       year ISO_code       countries                         region  hf_score  hf_rank  hf_quartile
# 1360  2008      SYR           Syria     Middle East & North Africa  5.457516    132.0          4.0
# 1338  2008      PAK        Pakistan                     South Asia  5.401850    133.0          4.0
# 1279  2008      ETH        Ethiopia             Sub-Saharan Africa  5.358855    134.0          4.0
# 1266  2008      COD  Congo, Dem. R.             Sub-Saharan Africa  5.351843    135.0          4.0
# 1374  2008      VEN       Venezuela  Latin America & the Caribbean  5.257879    136.0          4.0
# 1262  2008      TCD            Chad             Sub-Saharan Africa  5.212512    137.0          4.0
# 1238  2008      DZA         Algeria     Middle East & North Africa  5.153065    138.0          4.0
# 1328  2008      MMR         Myanmar                     South Asia  4.955303    139.0          4.0
# 1377  2008      ZWE        Zimbabwe             Sub-Saharan Africa  4.935571    140.0          4.0
# 1239  2008      AGO          Angola             Sub-Saharan Africa  4.823528    141.0          4.0
# 2009
#       year ISO_code          countries                         region  hf_score  hf_rank  hf_quartile
# 1138  2009      ETH           Ethiopia             Sub-Saharan Africa  5.498212    132.0          4.0
# 1125  2009      COD     Congo, Dem. R.             Sub-Saharan Africa  5.444295    133.0          4.0
# 1120  2009      CAF  Central Afr. Rep.             Sub-Saharan Africa  5.405058    134.0          4.0
# 1187  2009      MMR            Myanmar                     South Asia  5.361247    135.0          4.0
# 1121  2009      TCD               Chad             Sub-Saharan Africa  5.352743    136.0          4.0
# 1233  2009      VEN          Venezuela  Latin America & the Caribbean  5.283514    137.0          4.0
# 1098  2009      AGO             Angola             Sub-Saharan Africa  5.206898    138.0          4.0
# 1097  2009      DZA            Algeria     Middle East & North Africa  5.159941    139.0          4.0
# 1157  2009      IRN               Iran     Middle East & North Africa  5.131931    140.0          4.0
# 1236  2009      ZWE           Zimbabwe             Sub-Saharan Africa  4.927673    141.0          4.0
# 2010
#       year ISO_code          countries                         region  hf_score  hf_rank  hf_quartile
# 988   2010      ETH           Ethiopia             Sub-Saharan Africa  5.473526    144.0          4.0
# 975   2010      COD     Congo, Dem. R.             Sub-Saharan Africa  5.447902    145.0          4.0
# 1093  2010      YEM        Yemen, Rep.     Middle East & North Africa  5.425224    146.0          4.0
# 945   2010      AGO             Angola             Sub-Saharan Africa  5.237695    147.0          4.0
# 970   2010      CAF  Central Afr. Rep.             Sub-Saharan Africa  5.213756    148.0          4.0
# 1008  2010      IRN               Iran     Middle East & North Africa  5.199502    149.0          4.0
# 1091  2010      VEN          Venezuela  Latin America & the Caribbean  5.156619    150.0          4.0
# 944   2010      DZA            Algeria     Middle East & North Africa  5.139356    151.0          4.0
# 1039  2010      MMR            Myanmar                     South Asia  5.033975    152.0          4.0
# 1095  2010      ZWE           Zimbabwe             Sub-Saharan Africa  4.909415    153.0          4.0
# 2011
#      year ISO_code          countries                         region  hf_score  hf_rank  hf_quartile
# 792  2011      AGO             Angola             Sub-Saharan Africa  5.354951    144.0          4.0
# 938  2011      VEN          Venezuela  Latin America & the Caribbean  5.332458    145.0          4.0
# 818  2011      TCD               Chad             Sub-Saharan Africa  5.312640    146.0          4.0
# 791  2011      DZA            Algeria     Middle East & North Africa  5.211170    147.0          4.0
# 942  2011      ZWE           Zimbabwe             Sub-Saharan Africa  5.050736    148.0          4.0
# 822  2011      COD     Congo, Dem. R.             Sub-Saharan Africa  5.038327    149.0          4.0
# 817  2011      CAF  Central Afr. Rep.             Sub-Saharan Africa  4.969730    150.0          4.0
# 855  2011      IRN               Iran     Middle East & North Africa  4.842482    151.0          4.0
# 886  2011      MMR            Myanmar                     South Asia  4.779236    152.0          4.0
# 940  2011      YEM        Yemen, Rep.     Middle East & North Africa  4.710594    153.0          4.0
# 2012
#      year ISO_code          countries                         region  hf_score  hf_rank  hf_quartile
# 785  2012      VEN          Venezuela  Latin America & the Caribbean  5.225650    144.0          4.0
# 665  2012      TCD               Chad             Sub-Saharan Africa  5.132716    145.0          4.0
# 638  2012      DZA            Algeria     Middle East & North Africa  5.097404    146.0          4.0
# 789  2012      ZWE           Zimbabwe             Sub-Saharan Africa  5.084810    147.0          4.0
# 733  2012      MMR            Myanmar                     South Asia  5.050198    148.0          4.0
# 769  2012      SYR              Syria     Middle East & North Africa  4.866653    149.0          4.0
# 664  2012      CAF  Central Afr. Rep.             Sub-Saharan Africa  4.829057    150.0          4.0
# 669  2012      COD     Congo, Dem. R.             Sub-Saharan Africa  4.810664    151.0          4.0
# 787  2012      YEM        Yemen, Rep.     Middle East & North Africa  4.775506    152.0          4.0
# 702  2012      IRN               Iran     Middle East & North Africa  4.441783    153.0          4.0
# 2013
#      year ISO_code          countries                         region  hf_score  hf_rank  hf_quartile
# 508  2013      CAF  Central Afr. Rep.             Sub-Saharan Africa  5.300177    148.0          4.0
# 509  2013      TCD               Chad             Sub-Saharan Africa  5.275264    149.0          4.0
# 579  2013      MMR            Myanmar                     South Asia  5.190548    150.0          4.0
# 481  2013      DZA            Algeria     Middle East & North Africa  5.093421    151.0          4.0
# 632  2013      VEN          Venezuela  Latin America & the Caribbean  5.013857    152.0          4.0
# 513  2013      COD     Congo, Dem. R.             Sub-Saharan Africa  4.907996    153.0          4.0
# 562  2013      LBY              Libya     Middle East & North Africa  4.887965    154.0          4.0
# 634  2013      YEM        Yemen, Rep.     Middle East & North Africa  4.812705    155.0          4.0
# 547  2013      IRN               Iran     Middle East & North Africa  4.563809    156.0          4.0
# 616  2013      SYR              Syria     Middle East & North Africa  4.095028    157.0          4.0
# 2014
#      year ISO_code          countries                         region  hf_score  hf_rank  hf_quartile
# 349  2014      CAF  Central Afr. Rep.             Sub-Saharan Africa  5.306739    150.0          4.0
# 344  2014      BDI            Burundi             Sub-Saharan Africa  5.304037    151.0          4.0
# 322  2014      DZA            Algeria     Middle East & North Africa  5.194328    152.0          4.0
# 364  2014      EGY              Egypt     Middle East & North Africa  5.040691    153.0          4.0
# 354  2014      COD     Congo, Dem. R.             Sub-Saharan Africa  5.028850    154.0          4.0
# 477  2014      YEM        Yemen, Rep.     Middle East & North Africa  4.629535    155.0          4.0
# 475  2014      VEN          Venezuela  Latin America & the Caribbean  4.573730    156.0          4.0
# 388  2014      IRN               Iran     Middle East & North Africa  4.560686    157.0          4.0
# 405  2014      LBY              Libya     Middle East & North Africa  4.513248    158.0          4.0
# 459  2014      SYR              Syria     Middle East & North Africa  4.023595    159.0          4.0
# 2015
#      year ISO_code          countries                         region  hf_score  hf_rank  hf_quartile
# 195  2015      COD     Congo, Dem. R.             Sub-Saharan Africa  5.299806    150.0          4.0
# 190  2015      CAF  Central Afr. Rep.             Sub-Saharan Africa  5.124578    151.0          4.0
# 163  2015      DZA            Algeria     Middle East & North Africa  5.082655    152.0          4.0
# 185  2015      BDI            Burundi             Sub-Saharan Africa  5.055533    153.0          4.0
# 229  2015      IRN               Iran     Middle East & North Africa  4.946037    154.0          4.0
# 205  2015      EGY              Egypt     Middle East & North Africa  4.811136    155.0          4.0
# 246  2015      LBY              Libya     Middle East & North Africa  4.432118    156.0          4.0
# 316  2015      VEN          Venezuela  Latin America & the Caribbean  4.241750    157.0          4.0
# 318  2015      YEM        Yemen, Rep.     Middle East & North Africa  4.203442    158.0          4.0
# 300  2015      SYR              Syria     Middle East & North Africa  3.910826    159.0          4.0
# 2016
#      year ISO_code    countries                         region  hf_score  hf_rank  hf_quartile
# 68   2016      IRN         Iran     Middle East & North Africa  5.281225    153.0          4.0
# 24   2016      BDI      Burundi             Sub-Saharan Africa  5.167067    154.0          4.0
# 1    2016      DZA      Algeria     Middle East & North Africa  5.135886    155.0          4.0
# 44   2016      EGY        Egypt     Middle East & North Africa  4.807277    156.0          4.0
# 136  2016      SDN        Sudan             Sub-Saharan Africa  4.803024    157.0          4.0
# 86   2016      LBY        Libya     Middle East & North Africa  4.310283    158.0          4.0
# 69   2016      IRQ         Iraq     Middle East & North Africa  4.258014    159.0          4.0
# 159  2016      YEM  Yemen, Rep.     Middle East & North Africa  4.253278    160.0          4.0
# 157  2016      VEN    Venezuela  Latin America & the Caribbean  4.200724    161.0          4.0
# 141  2016      SYR        Syria     Middle East & North Africa  3.765827    162.0          4.0

# %% [markdown]
# ### What is the distribution of the HF score for countries?
# - The hf score for a country is calculated by taking the mean of the score over the years

# %%
sns.distplot(hf_df.groupby('countries').mean()['hf_score'])

# %% [markdown]
# - HF follows a bimodal distribution

# %% [markdown]
# ### Is this distribution different for different years?

# %%
for year in range(2008,2017):
    # Subset of year
    subset = hf_df[hf_df['year'] == year]
    
    # Draw the density plot
    sns.distplot(subset['hf_score'], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = year)
    
# Plot formatting
plt.legend(prop={'size': 16}, title = 'Year')
plt.title('Density Plot of HFI for different years')
plt.xlabel('HFI')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# - There is no significant difference in the distribution for different years

# %%
sns.boxplot(x="year", y="hf_score", data=hf_df)

# %% [markdown]
# - Year 2013 and 2016 have outliers, each of these years has one country (Syria) that has a much lower HFI score than the overall distribution pattern for that year
# - The later years (2012, 2016) have longer lower whiskers than upper whiskers. This indicates that the HFI scores vary more for the least positive quartile group than the most positive quartile group. This is most noticed in 2014, 2015.
# - The upper half of the box plot for all the years is bigger than the lower half. This indicates that the countries with more freedom vary more than the countries with less freedom.
# - The min HFI score has decreased over the years

# %% [markdown]
# ### What is the minimum HFI score over the years?

# %%
hf_df.groupby(['year'], sort=False)['hf_score'].min()
# Out:
# year
# 2016    3.765827
# 2015    3.910826
# 2014    4.023595
# 2013    4.095028
# 2012    4.441783
# 2011    4.710594
# 2010    4.909415
# 2009    4.927673
# 2008    4.823528
# Name: hf_score, dtype: float64

# %% [markdown]
# ##### What is the freedom difference between the least free country in 2008 and the least free country in 2016

# %%
3.765827 - 4.823528
# Out:
# -1.0577009999999998

# %% [markdown]
# ### What is the maximum HFI score over the years?

# %%
hf_df.groupby(['year'], sort=False)['hf_score'].max()
# Out:
# year
# 2016    8.887410
# 2015    8.876890
# 2014    8.921386
# 2013    8.971815
# 2012    8.999086
# 2011    9.027891
# 2010    9.028448
# 2009    9.052653
# 2008    9.126313
# Name: hf_score, dtype: float64

# %% [markdown]
# ##### What is the freedom difference between the most free country in 2008 and the most free country in 2016

# %%
8.887410 - 9.126313
# Out:
# -0.23890300000000053

# %% [markdown]
# ### Do different regions have different levels of freedom? <br> Have there been any interesting changes over time?

# %%
fig, ax = plt.subplots(figsize=(10,8))
for index, group in hf_country_years_complete.groupby(['region']):
    group_agg = group.groupby(['year']).aggregate(np.mean)
    group_agg.plot(y='hf_score', label=index, ax=ax)
ax.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# - 'North America' has consistently been the most free region
# - 'Western Europe' has much more freedom than Eastern Europe
# - 2012 onwards 'Middle East & North Africa' has less freedom than 'Sub-Saharan Africa'

# %% [markdown]
# ### What is the freedom distribution by region? <br> Do different regions have different distributions?

# %%
g = sns.FacetGrid(hf_df, col="region", col_wrap=4)
g = (g.map(sns.distplot,'hf_score').add_legend())

# %% [markdown]
# ### HFI distribution per region by year

# %%
# i = 0
# sns.set(rc={'figure.figsize':(15,8)})
# for region in hf_df['region'].unique():
#     plt.figure(i)
#     print(region)
#     sns.boxplot(x="year", y="hf_score", data=hf_df[hf_df['region'] == region], palette="Set3")
#     i+=1
#     plt.show()
    
g = sns.FacetGrid(hf_df, col="region", col_wrap=3)
g = (g.map(sns.boxplot,'year','hf_score',palette="Set3").add_legend())

# iterate over axes of FacetGrid
for ax in g.axes.flat:
    labels = ax.get_xticklabels() # get x labels
#     for i,l in enumerate(labels):
#         print(l.s)
#         print(type(l))
#         labels[i] = l[-2:]
#         if(i%2 == 0): labels[i] = '' # skip even labels
    ax.set_xticklabels(labels, rotation=-90) # set new labels
plt.show()

# %% [markdown]
# #### Eastern Europe
# - Negative Outlier: Russia (Ukraine (2014, 2015))
#
# #### Sub-Saharan Africa
# - Positive Outlier: Mauritius
#
# #### Latin America & the Caribbean
# - Positive Outlier: Chile, Uruguay (Costa Rica (2016))
# - Negative Outlier: Venezuela
#
# #### Western Europe
# - Negative Outlier: Iceland
#
# #### South Asia
# - Positive Outlier: Singapore
# - Negative Outlier: Myanmar, Pakistan
#
# #### East Asia
# - Positive Outlier: Hong Kong
# - Negative Outlier: China

# %% [markdown]
# ### HFI distibution per region by country

# %%
i = 0
sns.set(rc={'figure.figsize':(15,8)})
for region in hf['region'].unique():
    plt.figure(i)
    print(region)
    sns.boxplot(x="countries", y="hf_score", data=hf[hf['region'] == region], palette="Set3")
    i+=1
    plt.show()

# %% [markdown]
# ### HFI distribution of the top 15 influential countries

# %%
most_influential_countries_iso = [
    'USA', 'RUS','CHN','GBR','DEU',
    'FRA','JPN','ISR','SAU','ARE',
    'CAN','KOR','IRN','TUR','IND']

most_influential_countries = hf[hf['ISO_code'].isin(most_influential_countries_iso)]

# %%
most_influential_countries['countries'].unique()

# %%
sns.boxplot(x="ISO_code", y="hf_score", data=most_influential_countries, palette="Set3")

# %% [markdown]
# ## Colonies
# https://ourworldindata.org/colonialism

# %%
len(complete_data['countries'].unique())

# %%
colonies = pd.read_csv('temp.csv', sep=';')
